# %%
from bs4 import BeautifulSoup
from requests import get
import re
from models import (Base, session, Cars, engine)
import multiprocessing

import pandas as pd



faster = ["https://www.otomoto.pl/osobowe?page="+str(page)+"&search%5Badvanced_search_expanded%5D=true" for page in range(2,6000)]

# %%
# Dodawanie do bazy danych informacji z konkretnego ogłoszenia
def det(link,ID):

 
        
         

         mymap = {"Oferta od": " ", "Marka pojazdu": " ", "Model pojazdu": " ",
                          "Typ nadwozia": " ", "Generacja": " ", "Kolor": " ","Rodzaj koloru": " ",
                          "Rok produkcji": "", "Przebieg": "", "Pojemność skokowa": "",
                          "Rodzaj paliwa": " ", "Moc": " ", "Skrzynia biegów": " ",
                          "Napęd": " ", "Liczba drzwi": " ", "Liczba miejsc": " ",
                          "Kraj pochodzenia": " ", "Data pierwszej rejestracji w historii pojazdu": " ",
                          "Zarejestrowany w Polsce": " ", "Pierwszy właściciel (od nowości)": " ", "Bezwypadkowy": " ",
                          "Serwisowany w ASO": " ", "Stan": " ","Numer rejestracyjny pojazdu":" ",
                          "Spalanie W Mieście":" ","Spalanie Poza Miastem":" ","Wersja":" ","Emisja":" ",
                          "Okres gwarancji producenta":" ","Pokaż oferty z numerem VIN":" ","Możliwość finansowania":" ",
                          "Leasing": " "}
         

         df = pd.DataFrame(columns=["Oferta od", "Marka pojazdu", "Model pojazdu",
                      "Typ nadwozia", "Generacja", "Kolor" "Rodzaj koloru",
                      "Rok produkcji", "Przebieg", "Pojemność skokowa"
                      "Rodzaj paliwa", "Moc", "Skrzynia biegów",
                      "Napęd", "Liczba drzwi", "Liczba miejsc",
                      "Kraj pochodzenia", "Data pierwszej rejestracji w historii pojazdu",
                      "Zarejestrowany w Polsce", "Pierwszy właściciel (od nowości)", "Bezwypadkowy",
                      "Serwisowany w ASO", "Stan", "Numer rejestracyjny pojazdu",
                      "Spalanie W Mieście", "Spalanie Poza Miastem" , "Wersja", "Emisja",
                      "Okres gwarancji producenta", "Pokaż oferty z numerem VIN",
                      "Możliwość finansowania",
                      "Leasing"])
            
         page = get(link)
        
         bs = BeautifulSoup(page.content, 'html.parser')


         

         marka = bs.find_all(class_="ooa-162vy3d e18eslyg3")

         for info in marka:
    
            for key in mymap:
        
                if bool(re.search(f"{key}", info.get_text())):

                    new = re.sub(f"{key}", r"", info.get_text())
                    mymap[key] = new
            
            
         new_row_df = pd.DataFrame([mymap])

         # Dodawanie nowego wiersza do istniejącego DataFrame za pomocą concat
         df = pd.concat([df, new_row_df], ignore_index=True)
         display(df)

# %%
# pobieranie listy ofert i przejscie do kolejnej strony po ich zaladowaniu
def offerlist(url):

     page = get(url)
     bs = BeautifulSoup(page.content, 'html.parser')

     # id ogloszenia

     ID = list(map(lambda x: x.split("data-id=")[1].split("\"")[1], re.findall(r'data-id=["\d]+', str(bs.findAll(class_="ooa-yca59n e1oqyyyi0")))))




     # link do oferty
     linki = re.findall(r'https://www.otomoto.pl/[-\w\d/.]+', str(bs.findAll(target="_self")))

     i = 0
     for link in linki:
        
        det(link,ID)
        
     print(url)   

     if url == "https://www.otomoto.pl/osobowe" :
          
          url = "https://www.otomoto.pl/osobowe?page=2"

     else :

          print(url)
          page = str(int(re.findall(r'\d+', str(re.findall(r'page=\d+', url)))[0]) + 1)

          url = "https://www.otomoto.pl/osobowe?page="+page



     offerlist(url)

# %%
page = get("https://www.otomoto.pl/osobowe")

bs = BeautifulSoup(page.content, 'html.parser')

ID = re.findall(r'data-id=["\d]+', str(bs.findAll(class_="ooa-yca59n e1oqyyyi0")))

print(f"HALO {ID}")

offerlist("https://www.otomoto.pl/osobowe")
# Out:
# HALO ['data-id="6120733895"', 'data-id="6118461357"', 'data-id="6121123829"', 'data-id="', 'data-id="6120838670"', 'data-id="6120838608"', 'data-id="6120406122"', 'data-id="6120838751"', 'data-id="6120838790"', 'data-id="992', 'data-id="6119790868"', 'data-id="6119617564"', 'data-id="6118241809"', 'data-id="6120975992"', 'data-id="6120838681"', 'data-id="', 'data-id="6120838718"', 'data-id="6115972188"', 'data-id="6120838726"', 'data-id="6117087634"', 'data-id="6119033632"', 'data-id="6110365129"', 'data-id="6120791965"', 'data-id="6119940924"', 'data-id="6116190302"', 'data-id="6120838406"', 'data-id="6120838624"', 'data-id="6117810086"', 'data-id="6121056646"', 'data-id="6120838420"', 'data-id="6120838662"', 'data-id="6120837956"', 'data-id="6120885090"', 'data-id="6116870247"', 'data-id="6120836645"', 'data-id="']
#   Oferta od Marka pojazdu Model pojazdu   Typ nadwozia      Generacja  \
# 0  Prywatne          Opel         Corsa  Auta miejskie  D (2006-2014)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2011  114 300 km                            NaN
#
#      Moc  ...             Wersja Emisja Okres gwarancji producenta  \
# 0  87 KM  ...  1.4 16V 150 Jahre
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 398 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0     Firma       Peugeot          3008          SUV  I (2009-2016)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2011  267 000 km                            NaN
#
#       Moc  ...   Wersja       Emisja Okres gwarancji producenta  \
# 0  163 KM  ...  Hybrid4   CO299 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                    Tak          Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Perłowy         1 997 cm3       Hybryda
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia          Generacja  \
# 0     Firma        Toyota       Corolla        Kombi  Seria E21 (2019-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2020  134 700 km                            NaN
#
#       Moc  ...         Wersja Emisja Okres gwarancji producenta  \
# 0  116 KM  ...  1.2 T Comfort
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                    Tak          Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 197 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od  Marka pojazdu Model pojazdu Typ nadwozia         Generacja  \
# 0  Prywatne  Mercedes-Benz           GLE          SUV  W166 (2015-2019)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2017  119 000 km                            NaN
#
#       Moc  ...                         Wersja        Emisja  \
# 0  333 KM  ...  400 4Matic 9G-TRONIC AMG Line   CO2197 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                            Tak  Czarny       Metalik         2 996 cm3
#
#   Rodzaj paliwa
# 0       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia    Generacja  \
# 0  Prywatne      Chrysler       Voyager      Minivan  III (2001-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2004  330 000 km                            NaN
#
#       Moc  ...  Wersja Emisja Okres gwarancji producenta  \
# 0  147 KM  ...  2.4 SE
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing      Kolor  \
# 0                        Tak                                 Granatowy
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       2 429 cm3   Benzyna+LPG
#
# [1 rows x 34 columns]
#   Oferta od  Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0     Firma  Mercedes-Benz           GLA          SUV
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2018  73 000 km                            NaN
#
#       Moc  ...            Wersja Emisja Okres gwarancji producenta  \
# 0  122 KM  ...  180 7G-DCT Urban
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                    Tak     Tak  Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 595 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne         Honda         Civic      Kompakt  IX (2011-2017)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  133 000 km                            NaN
#
#       Moc  ...       Wersja        Emisja Okres gwarancji producenta  \
# 0  142 KM  ...  1.8 Comfort   CO2145 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Szary
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Perłowy         1 798 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne       Peugeot           308        Kombi  T9 (2014-2021)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2017  176 000 km                            NaN
#
#       Moc  ...                                           Wersja        Emisja  \
# 0  150 KM  ...  BlueHDi FAP 150 EAT6 Stop&Start GT-Line Edition   CO2108 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing      Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Niebieski                       1 997 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia          Generacja  \
# 0  Prywatne        Toyota       Corolla        Kombi  Seria E21 (2019-)
#
#   KolorRodzaj koloru Rok produkcji  Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2023  6 000 km                            NaN
#
#      Moc  ...              Wersja Emisja Okres gwarancji producenta  \
# 0  98 KM  ...  1.8 Hybrid Comfort
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Żółty
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 798 cm3   Benzyna+LPG
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne          Ford         Focus      Kompakt  Mk3 (2010-2018)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2014  289 000 km                            NaN
#
#       Moc  ...          Wersja        Emisja Okres gwarancji producenta  \
# 0  115 KM  ...  1.6 TDCi Trend   CO2117 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Srebrny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 560 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0     Firma       Peugeot           508        Kombi  I (2010-2018)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2015  210 212 km                            NaN
#
#       Moc  ...                             Wersja        Emisja  \
# 0  180 KM  ...  SW BlueHDi 180 EAT6 Stop&Start GT   CO2118 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czarny       Metalik         1 997 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od  Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0     Firma  Mercedes-Benz           GLS          SUV
#
#   KolorRodzaj koloru Rok produkcji  Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2018  8 000 km                            NaN
#
#       Moc  ...                           Wersja        Emisja  \
# 0  258 KM  ...  350 d 4Matic 9G-TRONIC AMG Line   CO2210 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czarny       Metalik         2 987 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia   Generacja  \
# 0  Prywatne          Audi            A4        Kombi  B9 (2015-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  216 703 km                            NaN
#
#       Moc  ...                          Wersja Emisja  \
# 0  190 KM  ...  Avant 2.0 TDI S tronic quattro
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czarny       Metalik         1 968 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia   Generacja  \
# 0  Prywatne          Ford          Kuga          SUV  II (2012-)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2017  98 000 km                            NaN
#
#       Moc  ...                    Wersja        Emisja  \
# 0  182 KM  ...  1.5 EcoBoost 4x4 ST-Line   CO2173 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing  Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Szary       Metalik         1 498 cm3
#
#   Rodzaj paliwa
# 0       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne        Suzuki         Swace        Kombi
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2023  28 000 km                            NaN
#
#      Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  98 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Żółty
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 798 cm3       Hybryda
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne          Audi            S8        Sedan  D3 (2002-2010)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2007  169 000 km                            NaN
#
#       Moc  ...           Wersja Emisja Okres gwarancji producenta  \
# 0  450 KM  ...  5.2 FSI Quattro
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                                                            Brązowy
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       5 204 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne           BMW       Seria 3        Sedan  G20/G21 (2019-)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2023  13 000 km                            NaN
#
#       Moc  ...        Wersja Emisja Okres gwarancji producenta  \
# 0  150 KM  ...  318d M Sport
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 995 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne          Audi            A4        Sedan  B8 (2007-2015)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2008  118 654 km                            NaN
#
#       Moc  ...   Wersja        Emisja Okres gwarancji producenta  \
# 0  143 KM  ...  2.0 TDI   CO2124 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 968 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne          Ford          EDGE          SUV
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2021  12 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  335 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing      Kolor  \
# 0                        Tak                                 Niebieski
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         2 700 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne         Skoda        Kodiaq          SUV
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2019  125 000 km                            NaN
#
#       Moc  ...                     Wersja Emisja Okres gwarancji producenta  \
# 0  240 KM  ...  2.0 Bi-TDI 4x4 RS DSG 7os
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing     Kolor  \
# 0                        Tak                                 Czerwony
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Perłowy         1 968 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne          Audi            A5        Coupe  8T (2007-2016)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2008  251 000 km                            NaN
#
#       Moc  ...           Wersja        Emisja Okres gwarancji producenta  \
# 0  240 KM  ...  3.0 TDI Quattro   CO2173 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         2 967 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od  Marka pojazdu Model pojazdu Typ nadwozia         Generacja  \
# 0  Prywatne  Mercedes-Benz       Klasa A    Auta małe  W169 (2004-2012)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2008  246 375 km                            NaN
#
#      Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  82 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Srebrny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 992 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne         Mazda          CX-3          SUV
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2017  81 232 km                            NaN
#
#       Moc  ...          Wersja Emisja Okres gwarancji producenta  \
# 0  120 KM  ...  2.0 Skypassion
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing       Kolor  \
# 0                        Tak                                 Inny kolor
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 998 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne          Seat        Toledo      Kompakt  III (2004-2009)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2005  310 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  102 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing      Kolor  \
# 0                        Tak                                 Niebieski
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 595 cm3   Benzyna+LPG
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne          Opel      Insignia        Kombi  A (2008-2017)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2011  245 000 km                            NaN
#
#       Moc  ...                            Wersja        Emisja  \
# 0  160 KM  ...  2.0 CDTI Sports Tourer Automatik   CO2169 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czarny       Perłowy         1 956 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne        Nissan       Qashqai          SUV  I (2007-2013)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2010  168 000 km                            NaN
#
#       Moc  ...     Wersja        Emisja Okres gwarancji producenta  \
# 0  114 KM  ...  1.6 I-Way   CO2155 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing       Kolor  \
# 0                        Tak                                 Inny kolor
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 598 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne       Maybach          Inny        Sedan
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  429 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  455 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing      Kolor  \
# 0                        Tak                                 Niebieski
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         4 663 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia    Generacja  \
# 0  Prywatne         Skoda       Octavia        Kombi  III (2013-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2020  110 078 km                            NaN
#
#       Moc  ...                Wersja        Emisja Okres gwarancji producenta  \
# 0  115 KM  ...  1.6 TDI SCR Ambition   CO2109 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Srebrny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 598 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia    Generacja  \
# 0  Prywatne       Citroën            C5        Sedan  III (2008-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2012  257 511 km                            NaN
#
#       Moc  ...                 Wersja        Emisja  \
# 0  163 KM  ...  HDi 165 FAP Exclusive   CO2129 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czarny       Metalik         1 997 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne       Renault          Clio      Kompakt  III (2005-2012)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2005  170 000 km                            NaN
#
#      Moc  ...               Wersja        Emisja Okres gwarancji producenta  \
# 0  75 KM  ...  1.2 16V Authentique   CO2135 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing      Kolor  \
# 0                        Tak                                 Niebieski
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 149 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne         Mazda          CX-3          SUV
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2018  48 150 km                            NaN
#
#       Moc  ...          Wersja        Emisja Okres gwarancji producenta  \
# 0  120 KM  ...  2.0 Skypassion   CO2137 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing       Kolor  \
# 0                        Tak                                 Inny kolor
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 998 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne         Skoda        Kodiaq          SUV
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2017  104 245 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  150 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing       Kolor  \
# 0                        Tak                                 Inny kolor
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 998 cm3        Diesel
#
# [1 rows x 34 columns]
# https://www.otomoto.pl/osobowe
#   Oferta od  Marka pojazdu Model pojazdu Typ nadwozia         Generacja  \
# 0  Prywatne  Mercedes-Benz       Klasa A    Auta małe  W169 (2004-2012)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2008  246 375 km                            NaN
#
#      Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  82 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Srebrny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 992 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne          Seat        Toledo      Kompakt  III (2004-2009)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2005  310 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  102 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing      Kolor  \
# 0                        Tak                                 Niebieski
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 595 cm3   Benzyna+LPG
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne         Mazda          CX-3          SUV
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2017  81 232 km                            NaN
#
#       Moc  ...          Wersja Emisja Okres gwarancji producenta  \
# 0  120 KM  ...  2.0 Skypassion
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing       Kolor  \
# 0                        Tak                                 Inny kolor
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 998 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne          Opel      Insignia        Kombi  A (2008-2017)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2011  245 000 km                            NaN
#
#       Moc  ...                            Wersja        Emisja  \
# 0  160 KM  ...  2.0 CDTI Sports Tourer Automatik   CO2169 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czarny       Perłowy         1 956 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne        Nissan       Qashqai          SUV  I (2007-2013)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2010  168 000 km                            NaN
#
#       Moc  ...     Wersja        Emisja Okres gwarancji producenta  \
# 0  114 KM  ...  1.6 I-Way   CO2155 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing       Kolor  \
# 0                        Tak                                 Inny kolor
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 598 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne       Maybach          Inny        Sedan
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  429 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  455 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing      Kolor  \
# 0                        Tak                                 Niebieski
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         4 663 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia    Generacja  \
# 0  Prywatne         Skoda       Octavia        Kombi  III (2013-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2020  110 078 km                            NaN
#
#       Moc  ...                Wersja        Emisja Okres gwarancji producenta  \
# 0  115 KM  ...  1.6 TDI SCR Ambition   CO2109 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Srebrny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 598 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia    Generacja  \
# 0  Prywatne       Citroën            C5        Sedan  III (2008-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2012  257 511 km                            NaN
#
#       Moc  ...                 Wersja        Emisja  \
# 0  163 KM  ...  HDi 165 FAP Exclusive   CO2129 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czarny       Metalik         1 997 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne       Renault          Clio      Kompakt  III (2005-2012)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2005  170 000 km                            NaN
#
#      Moc  ...               Wersja        Emisja Okres gwarancji producenta  \
# 0  75 KM  ...  1.2 16V Authentique   CO2135 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing      Kolor  \
# 0                        Tak                                 Niebieski
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 149 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne         Mazda          CX-3          SUV
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2018  48 150 km                            NaN
#
#       Moc  ...          Wersja        Emisja Okres gwarancji producenta  \
# 0  120 KM  ...  2.0 Skypassion   CO2137 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing       Kolor  \
# 0                        Tak                                 Inny kolor
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 998 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne         Skoda        Kodiaq          SUV
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2017  104 245 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  150 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing       Kolor  \
# 0                        Tak                                 Inny kolor
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 998 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia    Generacja  \
# 0  Prywatne         Skoda       Octavia        Kombi  III (2013-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2014  184 800 km                            NaN
#
#       Moc  ...            Wersja        Emisja Okres gwarancji producenta  \
# 0  140 KM  ...  1.4 TSI Ambition   CO2128 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing     Kolor  \
# 0                        Tak                                 Czerwony
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 395 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne          Audi            Q5          SUV  8R (2008-2016)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2012  158 000 km                            NaN
#
#       Moc  ...                    Wersja        Emisja  \
# 0  177 KM  ...  2.0 TDI Quattro S tronic   CO2159 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing    Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Srebrny                       1 968 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne          Opel         Astra        Coupe  H (2004-2014)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2006  361 600 km                            NaN
#
#       Moc  ...            Wersja        Emisja Okres gwarancji producenta  \
# 0  140 KM  ...  III 1.8 Essentia   CO2175 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Srebrny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 796 cm3   Benzyna+LPG
#
# [1 rows x 34 columns]
#   Oferta od  Marka pojazdu Model pojazdu Typ nadwozia     Generacja  \
# 0  Prywatne  Mercedes-Benz           CLK        Coupe  W209 (2002-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2003  290 000 km                            NaN
#
#       Moc  ...                   Wersja Emisja Okres gwarancji producenta  \
# 0  163 KM  ...  200 Kompressor Elegance
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing       Kolor  \
# 0                        Tak                                 Inny kolor
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 796 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne           BMW            X6          SUV  E71 (2008-2014)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2014  223 000 km                            NaN
#
#       Moc  ...             Wersja Emisja Okres gwarancji producenta  \
# 0  313 KM  ...  xDrive40d M Sport
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         2 993 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne         Skoda         Fabia      Kompakt  III (2014-2021)
#
#   KolorRodzaj koloru Rok produkcji  Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2020  8 850 km                            NaN
#
#      Moc  ...         Wersja Emisja Okres gwarancji producenta  \
# 0  95 KM  ...  1.0 TSI Style
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing     Kolor  \
# 0                        Tak                                 Czerwony
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik           999 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne          Ford   Grand C-MAX      Minivan
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2012  116 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  115 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Szary
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 560 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne          Opel         Mokka          SUV
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2015  157 000 km                            NaN
#
#       Moc  ...                  Wersja        Emisja  \
# 0  136 KM  ...  1.6 CDTI Cosmo S&S 4x4   CO2124 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing    Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Brązowy                       1 598 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne          Audi            A6        Kombi  C6 (2004-2011)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2009  247 234 km                            NaN
#
#       Moc  ...               Wersja        Emisja Okres gwarancji producenta  \
# 0  190 KM  ...  2.7 TDI Multitronic   CO2172 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         2 698 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia   Generacja  \
# 0  Prywatne         Volvo           V40      Kompakt  II (2012-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  196 000 km                            NaN
#
#       Moc  ...              Wersja Emisja Okres gwarancji producenta  \
# 0  120 KM  ...  D2 Drive-E Kinetic
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Perłowy         1 969 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia   Generacja  \
# 0  Prywatne       Renault        Megane        Kombi  IV (2016-)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2019  50 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  140 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Srebrny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 333 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne         Skoda         Fabia        Kombi  II (2007-2014)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2011  202 000 km                            NaN
#
#      Moc  ...                  Wersja Emisja Okres gwarancji producenta  \
# 0  70 KM  ...  1.2 HTP Combi Elegance
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Srebrny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 198 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu   Typ nadwozia Generacja  \
# 0  Prywatne     Chevrolet        Camaro  Auta miejskie
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2019  60 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  453 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       6 162 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne    Volkswagen          Golf        Kombi  VI (2008-2013)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2010  225 000 km                            NaN
#
#       Moc  ...                                     Wersja        Emisja  \
# 0  105 KM  ...  1.2 TSI BlueMotion Technology Comfortline   CO2114 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czarny       Metalik         1 197 cm3
#
#   Rodzaj paliwa
# 0       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu   Typ nadwozia      Generacja  \
# 0  Prywatne        Suzuki         Swift  Auta miejskie  V (2010-2017)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2011  227 000 km                            NaN
#
#      Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  94 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Srebrny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 242 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne          Ford         Focus      Kompakt  Mk3 (2010-2018)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2011  168 115 km                            NaN
#
#       Moc  ...                                    Wersja Emisja  \
# 0  149 KM  ...  1.6 EcoBoost Start-Stopp-System Titanium
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing     Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czerwony       Metalik         1 596 cm3
#
#   Rodzaj paliwa
# 0       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne          Opel      Insignia        Sedan  A (2008-2017)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2013  112 000 km                            NaN
#
#       Moc  ...         Wersja        Emisja Okres gwarancji producenta  \
# 0  180 KM  ...  1.6 T Edition   CO2186 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Srebrny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 598 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne           BMW       Seria 3        Sedan  G20/G21 (2019-)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2020  44 000 km                            NaN
#
#       Moc  ...              Wersja Emisja Okres gwarancji producenta  \
# 0  374 KM  ...  M340i xDrive sport
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         2 998 cm3       Benzyna
#
# [1 rows x 34 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 9
#       5 ID = re.findall(r'data-id=["\d]+', str(bs.findAll(class_="ooa-yca59n e1oqyyyi0")))
#       7 print(f"HALO {ID}")
# ----> 9 offerlist("https://www.otomoto.pl/osobowe")
#
# Cell In[3], line 37, in offerlist(url)
#      31      page = str(int(re.findall(r'\d+', str(re.findall(r'page=\d+', url)))[0]) + 1)
#      33      url = "https://www.otomoto.pl/osobowe?page="+page
# ---> 37 offerlist(url)
#
# Cell In[3], line 20, in offerlist(url)
#      17 i = 0
#      18 for link in linki:
# ---> 20    det(link,ID)
#      22 print(url)
#      24 if url == "https://www.otomoto.pl/osobowe" :
#
# Cell In[2], line 34, in det(link, ID)
#       8 mymap = {"Oferta od": " ", "Marka pojazdu": " ", "Model pojazdu": " ",
#       9                  "Typ nadwozia": " ", "Generacja": " ", "Kolor": " ","Rodzaj koloru": " ",
#      10                  "Rok produkcji": "", "Przebieg": "", "Pojemność skokowa": "",
#    (...)
#      17                  "Okres gwarancji producenta":" ","Pokaż oferty z numerem VIN":" ","Możliwość finansowania":" ",
#      18                  "Leasing": " "}
#      21 df = pd.DataFrame(columns=["Oferta od", "Marka pojazdu", "Model pojazdu",
#      22              "Typ nadwozia", "Generacja", "Kolor" "Rodzaj koloru",
#      23              "Rok produkcji", "Przebieg", "Pojemność skokowa"
#    (...)
#      31              "Możliwość finansowania",
#      32              "Leasing"])
# ---> 34 page = get(link)
#      36 bs = BeautifulSoup(page.content, 'html.parser')
#      41 marka = bs.find_all(class_="ooa-162vy3d e18eslyg3")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
    tekst = '''SzczegółyOferta odPrywatnePokaż oferty z numerem 
VINTakMa numer rejestracyjnyTakMarka pojazduFordModel pojazduMondeoGeneracjaMk5 
(2014-)Rok produkcji2015Przebieg146 000 kmPojemność skokowa1 997 cm3Rodzaj paliwaDieselMoc179
KMSkrzynia biegówAutomatycznaNapędNa przednie kołaSpalanie Poza Miastem4.0 l/100kmSpalanie W Mieście5
l/100kmTyp nadwoziaKombiEmisja CO2124 g/kmLiczba drzwi5Liczba miejsc5KolorCzarnyRodzaj koloruPerłowyKraj
pochodzeniaNiemcyData pierwszej rejestracji w historii pojazdu18 styczeń 2019Numer rejestracyjny pojazduZS945KLZarejestrowany
w PolsceTakBezwypadkowyTakSerwisowany w ASOTakStanUżywaneKup ten pojazd na ratyObliczVINWyświetl VIN'''

    mymap = {"Oferta od": " ", "Marka pojazdu": " ", "Model pojazdu": " ",
                          "Typ nadwozia": " ", "Generacja": " ", "Kolor": " ","Rodzaj koloru": " ",
                          "Rok produkcji": "", "Przebieg": "", "Pojemność skokowa": "",
                          "Rodzaj paliwa": " ", "Moc": " ", "Skrzynia biegów": " ",
                          "Napęd": " ", "Liczba drzwi": " ", "Liczba miejsc": " ",
                          "Kraj pochodzenia": " ", "Data pierwszej rejestracji w historii pojazdu": " ",
                          "Zarejestrowany w Polsce": " ", "Pierwszy właściciel (od nowości)": " ", "Bezwypadkowy": " ",
                          "Serwisowany w ASO": " ", "Stan": " ","Numer rejestracyjny pojazdu":" ",
                          "Spalanie W Mieście":" ","Spalanie Poza Miastem":" ","Wersja":" ","Emisja":" ",
                          "Okres gwarancji producenta":" ","Pokaż oferty z numerem VIN":" ","Możliwość finansowania":" ",
                          "Leasing": " "}


    
    tekst = re.sub(r"VIN", "vin", tekst)
    tekst = re.sub(r"ASO", "aso", tekst)
    tekst = re.sub(r"KM", "km", tekst)
    tekst = re.sub(r"CO2", "co2", tekst)

    # Dodajemy spacje przed dużymi literami
    tekst = re.sub(r"(?<!^)(?<!\s)([A-Z])", r" \1", tekst)

    # Przywracamy akronimy na ich miejsce
    tekst = re.sub("vin", "VIN", tekst)
    tekst = re.sub("aso", "ASO", tekst)
    tekst = re.sub("km", "KM", tekst)
    tekst = re.sub(r"co2", "CO2", tekst)
    print(tekst)
    
    for key in mymap:
   
      try:

        pattern = f"{key} [A-Za-z0-9łż]+[ ]?(\B[A-Z])?"
        match = re.search(pattern, tekst)
        info = match.group(0).strip()
        print(info)
      except:
        pass

    
    info = re.sub(r"(?![VIN|ASO]+)(\B[A-Z])", r" \1", tekst)

# %%
page = get("https://www.otomoto.pl/osobowe/oferta/audi-a5-lift-3xsline-177ps-sportback-xenon-skora-quattro-navi-shadowline-19-ID6GedgW.html")
bs = BeautifulSoup(page.content, 'html.parser')

marka = bs.find_all(class_="ooa-162vy3d e18eslyg3")

mymap = {"Oferta od": " ", "Marka pojazdu": " ", "Model pojazdu": " ",
                          "Typ nadwozia": " ", "Generacja": " ", "Kolor": " ","Rodzaj koloru": " ",
                          "Rok produkcji": "", "Przebieg": "", "Pojemność skokowa": "",
                          "Rodzaj paliwa": " ", "Moc": " ", "Skrzynia biegów": " ",
                          "Napęd": " ", "Liczba drzwi": " ", "Liczba miejsc": " ",
                          "Kraj pochodzenia": " ", "Data pierwszej rejestracji w historii pojazdu": " ",
                          "Zarejestrowany w Polsce": " ", "Pierwszy właściciel (od nowości)": " ", "Bezwypadkowy": " ",
                          "Serwisowany w ASO": " ", "Stan": " ","Numer rejestracyjny pojazdu":" ",
                          "Spalanie W Mieście":" ","Spalanie Poza Miastem":" ","Wersja":" ","Emisja":" ",
                          "Okres gwarancji producenta":" ","Pokaż oferty z numerem VIN":" ","Możliwość finansowania":" ",
                          "Leasing": " "}

marka = bs.find_all(class_="ooa-162vy3d e18eslyg3")

for info in marka:
    
    for key in mymap:
        
            if bool(re.search(f"{key}", info.get_text())):

                new = re.sub(f"{key}", r"", info.get_text())
                mymap[key] = new
print(mymap)
