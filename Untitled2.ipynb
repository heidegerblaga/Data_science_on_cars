# %%
from bs4 import BeautifulSoup
from requests import get
import re
from models import (Base, session, Cars, engine)
import multiprocessing

import pandas as pd



faster = ["https://www.otomoto.pl/osobowe?page="+str(page)+"&search%5Badvanced_search_expanded%5D=true" for page in range(2,6000)]

# %%
# Dodawanie do bazy danych informacji z konkretnego ogłoszenia
def det(link,ID):

 
        
         

         mymap = {"Oferta od": " ", "Marka pojazdu": " ", "Model pojazdu": " ",
                          "Typ nadwozia": " ", "Generacja": " ", "Kolor": " ","Rodzaj koloru": " ",
                          "Rok produkcji": "", "Przebieg": "", "Pojemność skokowa": "",
                          "Rodzaj paliwa": " ", "Moc": " ", "Skrzynia biegów": " ",
                          "Napęd": " ", "Liczba drzwi": " ", "Liczba miejsc": " ",
                          "Kraj pochodzenia": " ", "Data pierwszej rejestracji w historii pojazdu": " ",
                          "Zarejestrowany w Polsce": " ", "Pierwszy właściciel (od nowości)": " ", "Bezwypadkowy": " ",
                          "Serwisowany w ASO": " ", "Stan": " ","Numer rejestracyjny pojazdu":" ",
                          "Spalanie W Mieście":" ","Spalanie Poza Miastem":" ","Wersja":" ","Emisja":" ",
                          "Okres gwarancji producenta":" ","Pokaż oferty z numerem VIN":" ","Możliwość finansowania":" ",
                          "Leasing": " "}
         

         df = pd.DataFrame(columns=["Oferta od", "Marka pojazdu", "Model pojazdu",
                      "Typ nadwozia", "Generacja", "Kolor" "Rodzaj koloru",
                      "Rok produkcji", "Przebieg", "Pojemność skokowa"
                      "Rodzaj paliwa", "Moc", "Skrzynia biegów",
                      "Napęd", "Liczba drzwi", "Liczba miejsc",
                      "Kraj pochodzenia", "Data pierwszej rejestracji w historii pojazdu",
                      "Zarejestrowany w Polsce", "Pierwszy właściciel (od nowości)", "Bezwypadkowy",
                      "Serwisowany w ASO", "Stan", "Numer rejestracyjny pojazdu",
                      "Spalanie W Mieście", "Spalanie Poza Miastem" , "Wersja", "Emisja",
                      "Okres gwarancji producenta", "Pokaż oferty z numerem VIN",
                      "Możliwość finansowania",
                      "Leasing"])
            
         page = get(link)
        
         bs = BeautifulSoup(page.content, 'html.parser')


         

         marka = bs.find_all(class_="ooa-162vy3d e18eslyg3")

         for info in marka:
    
            for key in mymap:
        
                if bool(re.search(f"{key}", info.get_text())):

                    new = re.sub(f"{key}", r"", info.get_text())
                    mymap[key] = new
            
            
         new_row_df = pd.DataFrame([mymap])

         # Dodawanie nowego wiersza do istniejącego DataFrame za pomocą concat
         df = pd.concat([df, new_row_df], ignore_index=True)
         display(df)

# %%
# pobieranie listy ofert i przejscie do kolejnej strony po ich zaladowaniu
def offerlist(url):

     page = get(url)
     bs = BeautifulSoup(page.content, 'html.parser')

     # id ogloszenia

     ID = list(map(lambda x: x.split("data-id=")[1].split("\"")[1], re.findall(r'data-id=["\d]+', str(bs.findAll(class_="ooa-yca59n e1oqyyyi0")))))




     # link do oferty
     linki = re.findall(r'https://www.otomoto.pl/[-\w\d/.]+', str(bs.findAll(target="_self")))

     i = 0
     for link in linki:
        
        det(link,ID)
        
     print(url)   

     if url == "https://www.otomoto.pl/osobowe" :
          
          url = "https://www.otomoto.pl/osobowe?page=2"

     else :

          print(url)
          page = str(int(re.findall(r'\d+', str(re.findall(r'page=\d+', url)))[0]) + 1)

          url = "https://www.otomoto.pl/osobowe?page="+page



     offerlist(url)

# %%
page = get("https://www.otomoto.pl/osobowe")

bs = BeautifulSoup(page.content, 'html.parser')

ID = re.findall(r'data-id=["\d]+', str(bs.findAll(class_="ooa-yca59n e1oqyyyi0")))

print(f"HALO {ID}")

offerlist("https://www.otomoto.pl/osobowe")
# Out:
# HALO []
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0     Firma           BMW            X1          SUV  F48 (2015-2022)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  186 000 km                            NaN
#
#       Moc  ...                Wersja Emisja Okres gwarancji producenta  \
# 0  150 KM  ...  sDrive18d Sport Line
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 995 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne          Ford        Fusion        Sedan
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2018  177 000 km                            NaN
#
#       Moc  ...                 Wersja Emisja Okres gwarancji producenta  \
# 0  240 KM  ...  2.0 EcoBoost Titanium
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 999 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0     Firma         Dodge    Challenger        Coupe
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2019  55 000 km                            NaN
#
#       Moc  ...         Wersja Emisja Okres gwarancji producenta  \
# 0  492 KM  ...  6.4 Scat Pack
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                    Tak          Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0        Matowy         6 417 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia   Generacja  \
# 0  Prywatne         Dacia        Duster          SUV  II (2017-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2018  110 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  110 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 500 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia    Generacja  \
# 0     Firma         Mazda             6        Kombi  III (2012-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2017  189 000 km                            NaN
#
#       Moc  ...                            Wersja        Emisja  \
# 0  165 KM  ...  Kombi SKYACTIV-G 165 Center-Line   CO2150 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czarny       Perłowy         1 998 cm3
#
#   Rodzaj paliwa
# 0       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne          Ford          Kuga          SUV
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  116 000 km                            NaN
#
#       Moc  ...                     Wersja Emisja Okres gwarancji producenta  \
# 0  150 KM  ...  1.5 EcoBoost 2x4 Titanium
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 498 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia   Generacja  \
# 0  Prywatne       Renault        Megane      Kompakt  IV (2016-)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2017  78 454 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  115 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing      Kolor  \
# 0                        Tak                                 Niebieski
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 598 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne           BMW       Seria 1      Kompakt  F20/F21 (2011-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2013  219 400 km                            NaN
#
#       Moc  ...           Wersja        Emisja Okres gwarancji producenta  \
# 0  136 KM  ...  116i Sport Line   CO2129 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 598 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne          Audi            Q7          SUV  I (2005-2015)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2007  267 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  350 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing       Kolor  \
# 0                        Tak                                 Inny kolor
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       4 163 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne          Opel         Astra        Kombi  J (2009-2019)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2013  216 000 km                            NaN
#
#       Moc  ...             Wersja        Emisja Okres gwarancji producenta  \
# 0  164 KM  ...  2.0 CDTI Exklusiv   CO2124 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Szary
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 956 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne          Opel         Astra        Kombi  H (2004-2014)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2005  163 000 km                            NaN
#
#      Moc  ...               Wersja        Emisja Okres gwarancji producenta  \
# 0  90 KM  ...  1.4 Caravan Edition   CO2146 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Szary
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 364 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne        Nissan       Qashqai          SUV  II (2013-2021)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2014  163 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  130 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing      Kolor  \
# 0                        Tak                                 Granatowy
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 598 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia   Generacja  \
# 0     Firma          Ford          Kuga          SUV  II (2012-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2017  104 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  150 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing       Kolor  \
# 0                        Tak                                 Inny kolor
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 995 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne    Volkswagen        Tiguan          SUV  I (2007-2016)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2011  259 000 km                            NaN
#
#       Moc  ...                         Wersja Emisja  \
# 0  150 KM  ...  1.4 TSI 4Motion Sport & Style
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czarny                       1 390 cm3
#
#   Rodzaj paliwa
# 0       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia   Generacja  \
# 0  Prywatne          Ford          Kuga          SUV  II (2012-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2018  153 000 km                            NaN
#
#       Moc  ...                     Wersja        Emisja  \
# 0  176 KM  ...  1.5 EcoBoost 4x4 Titanium   CO2173 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing  Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Biały        Matowy         1 498 cm3
#
#   Rodzaj paliwa
# 0       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne          Audi            A4        Kombi  B8 (2007-2015)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2014  210 000 km                            NaN
#
#       Moc  ...                    Wersja Emisja Okres gwarancji producenta  \
# 0  177 KM  ...  2.0 TDI Quattro S tronic
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Brązowy
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 968 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia     Generacja  \
# 0     Firma    Volkswagen          Golf        Kombi  VIII (2020-)
#
#   KolorRodzaj koloru Rok produkcji Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2023                                     NaN
#
#       Moc  ...                  Wersja Emisja Okres gwarancji producenta  \
# 0  130 KM  ...  VIII 1.5 TSI EVO Style
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                    Tak     Tak  Żółty
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 498 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne          Opel         Corsa      Kompakt  D (2006-2014)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2009  221 000 km                            NaN
#
#      Moc  ...         Wersja        Emisja Okres gwarancji producenta  \
# 0  90 KM  ...  1.4 16V Enjoy   CO2144 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing     Kolor  \
# 0                        Tak                                 Błękitny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 364 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne     Chevrolet          Trax          SUV
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2013  95 601 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  115 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Brązowy
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 598 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne     Chevrolet          Trax          SUV
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2013  136 449 km                            NaN
#
#       Moc  ...    Wersja        Emisja Okres gwarancji producenta  \
# 0  130 KM  ...  1.7 D LT   CO2120 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Szary
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 686 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu   Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne          Jeep  Grand Cherokee          SUV  IV (2010-2021)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2020  29 000 km                            NaN
#
#       Moc  ...            Wersja        Emisja Okres gwarancji producenta  \
# 0  352 KM  ...  Gr 5.7 V8 Summit   CO2304 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         5 654 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne           BMW       Seria 1      Kompakt  F20/F21 (2011-)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2019  55 523 km                            NaN
#
#       Moc  ... Wersja        Emisja Okres gwarancji producenta  \
# 0  136 KM  ...   118i   CO2129 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Szary
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 499 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne          Opel      Insignia        Kombi  A (2008-2017)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2014  136 900 km                            NaN
#
#       Moc  ...              Wersja        Emisja Okres gwarancji producenta  \
# 0  163 KM  ...  2.0 CDTI Executive   CO2149 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                            Tak  Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Perłowy         1 956 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne          Opel        Vivaro      Minivan  II (2014-2019)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  325 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  145 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing      Kolor  \
# 0                        Tak                                 Niebieski
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 598 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne          Audi            S3      Kompakt  8L (1996-2003)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2001  273 000 km                            NaN
#
#       Moc  ...        Wersja Emisja Okres gwarancji producenta  \
# 0  224 KM  ...  1.8T Quattro
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Żółty
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 781 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne          MINI      Cooper S    Kabriolet
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2009  217 000 km                            NaN
#
#       Moc  ...  Wersja Emisja Okres gwarancji producenta  \
# 0  175 KM  ...  Cabrio
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Beżowy
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 598 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne           BMW            X5          SUV  E70 (2006-2013)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2011  94 700 km                            NaN
#
#       Moc  ...       Wersja Emisja Okres gwarancji producenta  \
# 0  286 KM  ...  3.5d xDrive
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Srebrny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       2 993 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od  Marka pojazdu Model pojazdu Typ nadwozia     Generacja  \
# 0  Prywatne  Mercedes-Benz       Klasa A        Sedan  W177 (2018-)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2020  38 000 km                            NaN
#
#       Moc  ...               Wersja Emisja Okres gwarancji producenta  \
# 0  163 KM  ...  200 AMG Line 7G-DCT
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Szary
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 332 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia    Generacja  \
# 0  Prywatne          Ford        Mondeo        Kombi  Mk5 (2014-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2018  224 500 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  150 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing       Kolor  \
# 0                        Tak                                 Inny kolor
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 997 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia    Generacja  \
# 0  Prywatne         Volvo           V70        Kombi  III (2007-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2015  216 294 km                            NaN
#
#       Moc  ...                Wersja        Emisja Okres gwarancji producenta  \
# 0  181 KM  ...  D4 Geartronic Summum   CO2122 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Perłowy         1 969 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia  Generacja  \
# 0  Prywatne          Seat         Ibiza    Auta małe  V (2017-)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2018  81 100 km                            NaN
#
#      Moc  ...          Wersja Emisja Okres gwarancji producenta  \
# 0  95 KM  ...  1.0 TSI S&S FR
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0        Matowy           999 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne          Ford         Focus        Kombi  Mk3 (2010-2018)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2014  85 000 km                            NaN
#
#       Moc  ...                      Wersja        Emisja  \
# 0  125 KM  ...  1.0 EcoBoost mHEV Titanium   CO2124 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czarny       Metalik           999 cm3
#
#   Rodzaj paliwa
# 0       Benzyna
#
# [1 rows x 34 columns]
# https://www.otomoto.pl/osobowe
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia            Generacja  \
# 0     Firma           BMW       Seria 3        Kombi  F30/F31 (2012-2020)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  141 887 km                            NaN
#
#       Moc  ...           Wersja Emisja Okres gwarancji producenta  \
# 0  190 KM  ...  320d Sport Line
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                    Tak          Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 995 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne           BMW            X5          SUV  F15 (2013-2018)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2018  140 800 km                            NaN
#
#       Moc  ...     Wersja Emisja Okres gwarancji producenta  \
# 0  231 KM  ...  xDrive25d
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 995 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne          Audi            A6        Sedan  C6 (2004-2011)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2004  234 350 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  177 KM  ...    2.4
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         2 393 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu   Typ nadwozia Generacja  \
# 0  Prywatne       Citroën            C2  Auta miejskie
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2010  125 000 km                            NaN
#
#      Moc  ...   Wersja        Emisja Okres gwarancji producenta  \
# 0  73 KM  ...  1.4 VTR   CO2143 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 360 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia   Generacja  \
# 0  Prywatne          Audi            A5        Coupe  F5 (2016-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2019  118 000 km                            NaN
#
#       Moc  ...                            Wersja        Emisja  \
# 0  150 KM  ...  Sportback 2.0 TDI S tronic sport   CO2113 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing  Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Szary       Metalik         1 968 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne          Fiat       Fiorino      Minivan
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  200 000 km                            NaN
#
#      Moc  ...                                Wersja        Emisja  \
# 0  75 KM  ...  Qubo 1.3 Multijet 16V Trekking Euro5   CO2113 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing  Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Biały                       1 248 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od  Marka pojazdu Model pojazdu Typ nadwozia         Generacja  \
# 0  Prywatne  Mercedes-Benz       Klasa S        Sedan  W220 (1998-2005)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2005  242 000 km                            NaN
#
#       Moc  ... Wersja        Emisja Okres gwarancji producenta  \
# 0  245 KM  ...    350   CO2266 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         3 724 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne          MINI    Countryman          SUV
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2010  169 500 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  184 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing     Kolor  \
# 0                        Tak                                 Czerwony
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 598 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne    Volkswagen        Tiguan          SUV  I (2007-2016)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2013  180 000 km                            NaN
#
#       Moc  ...                        Wersja Emisja  \
# 0  140 KM  ...  2.0 TDI 4Mot Sport&Style DSG
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czarny       Metalik         1 968 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0     Firma          Ford        Escape          SUV
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2019  86 840 km                            NaN
#
#       Moc  ...               Wersja Emisja Okres gwarancji producenta  \
# 0  182 KM  ...  1.5 EcoBoost AWD SE
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Zielony
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 499 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia    Generacja  \
# 0  Prywatne       Peugeot           508        Kombi  II (2018- )
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2020  70 000 km                            NaN
#
#       Moc  ... Wersja       Emisja Okres gwarancji producenta  \
# 0  181 KM  ...          CO233 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Perłowy         1 598 cm3       Hybryda
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia   Generacja  \
# 0  Prywatne          Audi            Q7          SUV  II (2015-)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2019  43 500 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  251 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 994 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia   Generacja  \
# 0  Prywatne          Audi            A8        Sedan  D4 (2010-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2011  270 000 km                            NaN
#
#       Moc  ...           Wersja        Emisja Okres gwarancji producenta  \
# 0  350 KM  ...  4.2 TDI Quattro   CO2199 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Perłowy         4 134 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne       Renault  Grand Scenic      Minivan  II (2009-2016)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2013  125 000 km                            NaN
#
#       Moc  ...                        Wersja Emisja  \
# 0  110 KM  ...  dCi 110 FAP EDC Bose Edition
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing    Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Brązowy       Metalik         1 461 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia            Generacja  \
# 0  Prywatne           BMW       Seria 3        Sedan  F30/F31 (2012-2020)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  179 000 km                            NaN
#
#       Moc  ... Wersja        Emisja Okres gwarancji producenta  \
# 0  136 KM  ...   318i   CO2119 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                            Tak  Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 499 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od  Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne  Mercedes-Benz           GLS          SUV
#
#   KolorRodzaj koloru Rok produkcji  Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2022  9 000 km                            NaN
#
#       Moc  ...       Wersja Emisja Okres gwarancji producenta  \
# 0  367 KM  ...  450 4-Matic
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       2 999 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne         Honda          CR-V          SUV  IV (2012-2018)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  185 000 km                            NaN
#
#       Moc  ...         Wersja        Emisja Okres gwarancji producenta  \
# 0  155 KM  ...  2.0 Lifestyle   CO2179 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Szary
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 997 cm3   Benzyna+LPG
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne          Opel         Astra        Kombi  K (2015-2021)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2017  200 000 km                            NaN
#
#       Moc  ...                               Wersja Emisja  \
# 0  110 KM  ...  1.6 D (CDTI) Sports Tourer Business
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing  Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Biały                       1 598 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia    Generacja  \
# 0  Prywatne          Ford         Focus      Kompakt  Mk4 (2018-)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2021  47 000 km                            NaN
#
#       Moc  ...                  Wersja        Emisja  \
# 0  150 KM  ...  1.5 EcoBoost ST-Line X   CO2127 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing      Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Niebieski                       1 499 cm3
#
#   Rodzaj paliwa
# 0       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od  Marka pojazdu Model pojazdu Typ nadwozia     Generacja  \
# 0  Prywatne  Mercedes-Benz       Klasa A      Kompakt  W176 (2012-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  146 800 km                            NaN
#
#       Moc  ...          Wersja        Emisja Okres gwarancji producenta  \
# 0  136 KM  ...  200 d AMG Line   CO2106 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         2 143 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od  Marka pojazdu Model pojazdu Typ nadwozia         Generacja  \
# 0  Prywatne  Mercedes-Benz       Klasa C        Kombi  W205 (2014-2021)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2015  188 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  136 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Srebrny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 598 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne         Volvo           S90        Sedan
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  119 018 km                            NaN
#
#       Moc  ...          Wersja        Emisja Okres gwarancji producenta  \
# 0  254 KM  ...  T5 Inscription   CO2149 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Szary
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 969 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne          Seat        Toledo        Sedan  IV (2012-2018)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  184 000 km                            NaN
#
#      Moc  ...             Wersja        Emisja Okres gwarancji producenta  \
# 0  90 KM  ...  1.4 TDI Reference   CO2112 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Srebrny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 422 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0     Firma    Volkswagen      Multivan      Minivan
#
#   KolorRodzaj koloru Rok produkcji Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2023     5 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  218 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                    Tak     Tak  Srebrny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 395 cm3       Hybryda
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0     Firma    Volkswagen    California      Minivan
#
#   KolorRodzaj koloru Rok produkcji Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2023                                     NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  150 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                    Tak     Tak  Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 968 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia          Generacja  \
# 0  Prywatne        Toyota       Corolla        Sedan  Seria E21 (2019-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2019  222 000 km                            NaN
#
#       Moc  ...       Wersja Emisja Okres gwarancji producenta  \
# 0  132 KM  ...  1.6 Comfort
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 598 cm3   Benzyna+LPG
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne       Renault        Espace      Minivan  V (2015-2023)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2016  74 500 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  160 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Szary
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 598 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia    Generacja  \
# 0  Prywatne          Ford        Mondeo        Kombi  Mk5 (2014-)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2019  193 000 km                            NaN
#
#       Moc  ...                        Wersja        Emisja  \
# 0  150 KM  ...  Turnier 2.0 EcoBlue Titanium   CO2128 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing       Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Inny kolor       Metalik         1 997 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu   Typ nadwozia       Generacja  \
# 0  Prywatne       Peugeot           308  Auta miejskie  T9 (2014-2021)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2015  153 000 km                            NaN
#
#       Moc  ...                               Wersja       Emisja  \
# 0  120 KM  ...  BlueHDi FAP 120 Stop & Start Allure   CO298 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing    Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Srebrny                       1 560 cm3
#
#   Rodzaj paliwa
# 0        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia        Generacja  \
# 0  Prywatne           Kia      Sportage          SUV  III (2010-2015)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2015  90 000 km                            NaN
#
#       Moc  ...               Wersja Emisja Okres gwarancji producenta  \
# 0  136 KM  ...  1.6 GDI 2WD Attract
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Biały
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Perłowy         1 591 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne          Audi            A5        Sedan  8T (2007-2016)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2010  235 000 km                            NaN
#
#       Moc  ...                     Wersja        Emisja  \
# 0  211 KM  ...  2.0 TFSI Quattro S tronic   CO2159 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing    Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Srebrny       Metalik         1 984 cm3
#
#   Rodzaj paliwa
# 0       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od  Marka pojazdu Model pojazdu Typ nadwozia         Generacja  \
# 0  Prywatne  Mercedes-Benz       Klasa C        Coupe  W205 (2014-2021)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2017  107 000 km                            NaN
#
#       Moc  ...                        Wersja        Emisja  \
# 0  245 KM  ...  300 Coupe 7G-TRONIC AMG Line   CO2146 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czarny       Metalik         1 991 cm3
#
#   Rodzaj paliwa
# 0       Benzyna
#
# [1 rows x 34 columns]
# https://www.otomoto.pl/osobowe?page=2
# https://www.otomoto.pl/osobowe?page=2
#   Oferta od  Marka pojazdu Model pojazdu Typ nadwozia         Generacja  \
# 0  Prywatne  Mercedes-Benz       Klasa C        Coupe  W205 (2014-2021)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2017  107 000 km                            NaN
#
#       Moc  ...                        Wersja        Emisja  \
# 0  245 KM  ...  300 Coupe 7G-TRONIC AMG Line   CO2146 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing   Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czarny       Metalik         1 991 cm3
#
#   Rodzaj paliwa
# 0       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne          Audi            Q5          SUV  8R (2008-2016)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2011  319 000 km                            NaN
#
#       Moc  ...           Wersja        Emisja Okres gwarancji producenta  \
# 0  143 KM  ...  2.0 TDI Quattro   CO2154 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 968 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne         Volvo           V50        Kombi
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2007  240 000 km                            NaN
#
#       Moc  ...        Wersja        Emisja Okres gwarancji producenta  \
# ...
# 0       Metalik         1 242 cm3       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne           BMW       Seria 2      Minivan
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2015  218 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  150 KM  ...   218d
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Złoty
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 995 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne       Renault        Captur          SUV  I (2013-2019)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2014  68 000 km                            NaN
#
#       Moc  ...                    Wersja        Emisja  \
# 0  120 KM  ...  1.2 TCe Helly Hansen EDC   CO2125 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing     Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czerwony       Metalik         1 197 cm3
#
#   Rodzaj paliwa
# 0       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne          Ford         S-Max      Minivan  I (2006-2015)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2013  233 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  163 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing   Kolor  \
# 0                        Tak                                 Czarny
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 997 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne       Citroën      Berlingo      Minivan  II (2008-2018)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2010  203 000 km                            NaN
#
#      Moc  ...       Wersja        Emisja Okres gwarancji producenta  \
# 0  92 KM  ...  1.6 HDi XTR   CO2129 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Zielony
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 560 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0     Firma    Volkswagen        Passat        Kombi  B8 (2014-2023)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2015  172 160 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  150 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing      Kolor  \
# 0                        Tak                    Tak     Tak  Niebieski
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 968 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu   Typ nadwozia    Generacja  \
# 0     Firma    Volkswagen        Touran  Auta miejskie  III (2015-)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2017  89 900 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  110 KM  ...
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Szary
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 598 cm3        Diesel
#
# [1 rows x 34 columns]
# https://www.otomoto.pl/osobowe?page=5
# https://www.otomoto.pl/osobowe?page=5
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia Generacja  \
# 0  Prywatne           BMW       Seria 2      Minivan
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2015  218 000 km                            NaN
#
#       Moc  ... Wersja Emisja Okres gwarancji producenta  \
# 0  150 KM  ...   218d
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing  Kolor  \
# 0                        Tak                                 Złoty
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0       Metalik         1 995 cm3        Diesel
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia      Generacja  \
# 0  Prywatne       Renault        Captur          SUV  I (2013-2019)
#
#   KolorRodzaj koloru Rok produkcji   Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2014  68 000 km                            NaN
#
#       Moc  ...                    Wersja        Emisja  \
# 0  120 KM  ...  1.2 TCe Helly Hansen EDC   CO2125 g/km
#
#   Okres gwarancji producenta Pokaż oferty z numerem VIN  \
# 0                                                   Tak
#
#   Możliwość finansowania Leasing     Kolor Rodzaj koloru Pojemność skokowa  \
# 0                                 Czerwony       Metalik         1 197 cm3
#
#   Rodzaj paliwa
# 0       Benzyna
#
# [1 rows x 34 columns]
#   Oferta od Marka pojazdu Model pojazdu Typ nadwozia       Generacja  \
# 0  Prywatne       Citroën      Berlingo      Minivan  II (2008-2018)
#
#   KolorRodzaj koloru Rok produkcji    Przebieg Pojemność skokowaRodzaj paliwa  \
# 0                NaN          2010  203 000 km                            NaN
#
#      Moc  ...       Wersja        Emisja Okres gwarancji producenta  \
# 0  92 KM  ...  1.6 HDi XTR   CO2129 g/km
#
#   Pokaż oferty z numerem VIN Możliwość finansowania Leasing    Kolor  \
# 0                        Tak                                 Zielony
#
#   Rodzaj koloru Pojemność skokowa Rodzaj paliwa
# 0                       1 560 cm3        Diesel
#
# [1 rows x 34 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 9
#       5 ID = re.findall(r'data-id=["\d]+', str(bs.findAll(class_="ooa-yca59n e1oqyyyi0")))
#       7 print(f"HALO {ID}")
# ----> 9 offerlist("https://www.otomoto.pl/osobowe")
#
# Cell In[3], line 37, in offerlist(url)
#      31      page = str(int(re.findall(r'\d+', str(re.findall(r'page=\d+', url)))[0]) + 1)
#      33      url = "https://www.otomoto.pl/osobowe?page="+page
# ---> 37 offerlist(url)
#
# Cell In[3], line 37, in offerlist(url)
#      31      page = str(int(re.findall(r'\d+', str(re.findall(r'page=\d+', url)))[0]) + 1)
#      33      url = "https://www.otomoto.pl/osobowe?page="+page
# ---> 37 offerlist(url)
#
#     [... skipping similar frames: offerlist at line 37 (2 times)]
#
# Cell In[3], line 37, in offerlist(url)
#      31      page = str(int(re.findall(r'\d+', str(re.findall(r'page=\d+', url)))[0]) + 1)
#      33      url = "https://www.otomoto.pl/osobowe?page="+page
# ---> 37 offerlist(url)
#
# Cell In[3], line 20, in offerlist(url)
#      17 i = 0
#      18 for link in linki:
# ---> 20    det(link,ID)
#      22 print(url)
#      24 if url == "https://www.otomoto.pl/osobowe" :
#
# Cell In[2], line 34, in det(link, ID)
#       8 mymap = {"Oferta od": " ", "Marka pojazdu": " ", "Model pojazdu": " ",
#       9                  "Typ nadwozia": " ", "Generacja": " ", "Kolor": " ","Rodzaj koloru": " ",
#      10                  "Rok produkcji": "", "Przebieg": "", "Pojemność skokowa": "",
#    (...)
#      17                  "Okres gwarancji producenta":" ","Pokaż oferty z numerem VIN":" ","Możliwość finansowania":" ",
#      18                  "Leasing": " "}
#      21 df = pd.DataFrame(columns=["Oferta od", "Marka pojazdu", "Model pojazdu",
#      22              "Typ nadwozia", "Generacja", "Kolor" "Rodzaj koloru",
#      23              "Rok produkcji", "Przebieg", "Pojemność skokowa"
#    (...)
#      31              "Możliwość finansowania",
#      32              "Leasing"])
# ---> 34 page = get(link)
#      36 bs = BeautifulSoup(page.content, 'html.parser')
#      41 marka = bs.find_all(class_="ooa-162vy3d e18eslyg3")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
    tekst = '''SzczegółyOferta odPrywatnePokaż oferty z numerem 
VINTakMa numer rejestracyjnyTakMarka pojazduFordModel pojazduMondeoGeneracjaMk5 
(2014-)Rok produkcji2015Przebieg146 000 kmPojemność skokowa1 997 cm3Rodzaj paliwaDieselMoc179
KMSkrzynia biegówAutomatycznaNapędNa przednie kołaSpalanie Poza Miastem4.0 l/100kmSpalanie W Mieście5
l/100kmTyp nadwoziaKombiEmisja CO2124 g/kmLiczba drzwi5Liczba miejsc5KolorCzarnyRodzaj koloruPerłowyKraj
pochodzeniaNiemcyData pierwszej rejestracji w historii pojazdu18 styczeń 2019Numer rejestracyjny pojazduZS945KLZarejestrowany
w PolsceTakBezwypadkowyTakSerwisowany w ASOTakStanUżywaneKup ten pojazd na ratyObliczVINWyświetl VIN'''

    mymap = {"Oferta od": " ", "Marka pojazdu": " ", "Model pojazdu": " ",
                          "Typ nadwozia": " ", "Generacja": " ", "Kolor": " ","Rodzaj koloru": " ",
                          "Rok produkcji": "", "Przebieg": "", "Pojemność skokowa": "",
                          "Rodzaj paliwa": " ", "Moc": " ", "Skrzynia biegów": " ",
                          "Napęd": " ", "Liczba drzwi": " ", "Liczba miejsc": " ",
                          "Kraj pochodzenia": " ", "Data pierwszej rejestracji w historii pojazdu": " ",
                          "Zarejestrowany w Polsce": " ", "Pierwszy właściciel (od nowości)": " ", "Bezwypadkowy": " ",
                          "Serwisowany w ASO": " ", "Stan": " ","Numer rejestracyjny pojazdu":" ",
                          "Spalanie W Mieście":" ","Spalanie Poza Miastem":" ","Wersja":" ","Emisja":" ",
                          "Okres gwarancji producenta":" ","Pokaż oferty z numerem VIN":" ","Możliwość finansowania":" ",
                          "Leasing": " "}


    
    tekst = re.sub(r"VIN", "vin", tekst)
    tekst = re.sub(r"ASO", "aso", tekst)
    tekst = re.sub(r"KM", "km", tekst)
    tekst = re.sub(r"CO2", "co2", tekst)

    # Dodajemy spacje przed dużymi literami
    tekst = re.sub(r"(?<!^)(?<!\s)([A-Z])", r" \1", tekst)

    # Przywracamy akronimy na ich miejsce
    tekst = re.sub("vin", "VIN", tekst)
    tekst = re.sub("aso", "ASO", tekst)
    tekst = re.sub("km", "KM", tekst)
    tekst = re.sub(r"co2", "CO2", tekst)
    print(tekst)
    
    for key in mymap:
   
      try:

        pattern = f"{key} [A-Za-z0-9łż]+[ ]?(\B[A-Z])?"
        match = re.search(pattern, tekst)
        info = match.group(0).strip()
        print(info)
      except:
        pass

    
    info = re.sub(r"(?![VIN|ASO]+)(\B[A-Z])", r" \1", tekst)
# Out:
# Szczegóły Oferta od Prywatne Pokaż oferty z numerem
# VIN Tak Ma numer rejestracyjny Tak Marka pojazdu Ford Model pojazdu Mondeo Generacja Mk5
# (2014-) Rok produkcji2015 Przebieg146 000 KM Pojemność skokowa1 997 cm3 Rodzaj paliwa Diesel Moc179
# KM Skrzynia biegów Automatyczna Napęd Na przednie koła Spalanie Poza Miastem4.0 l/100KM Spalanie W Mieście5
# l/100KM Typ nadwozia Kombi Emisja CO2124 g/KM Liczba drzwi5 Liczba miejsc5 Kolor Czarny Rodzaj koloru Perłowy Kraj
# pochodzenia Niemcy Data pierwszej rejestracji w historii pojazdu18 styczeń 2019 Numer rejestracyjny pojazdu Z S945 K L Zarejestrowany
# w Polsce Tak Bezwypadkowy Tak Serwisowany w ASO Tak Stan Używane Kup ten pojazd na raty ObliczVIN Wyświetl VIN
# Oferta od Prywatne
# Marka pojazdu Ford
# Model pojazdu Mondeo
# Typ nadwozia Kombi
# Generacja Mk5
# Kolor Czarny
# Rodzaj koloru Perłowy
# Rodzaj paliwa Diesel
# Skrzynia biegów Automatyczna
# Napęd Na
# Bezwypadkowy Tak
# Serwisowany w ASO Tak
# Stan Używane
# Numer rejestracyjny pojazdu Z
# Emisja CO2124

# %%
page = get("https://www.otomoto.pl/osobowe/oferta/audi-a5-lift-3xsline-177ps-sportback-xenon-skora-quattro-navi-shadowline-19-ID6GedgW.html")
bs = BeautifulSoup(page.content, 'html.parser')

marka = bs.find_all(class_="ooa-162vy3d e18eslyg3")

mymap = {"Oferta od": " ", "Marka pojazdu": " ", "Model pojazdu": " ",
                          "Typ nadwozia": " ", "Generacja": " ", "Kolor": " ","Rodzaj koloru": " ",
                          "Rok produkcji": "", "Przebieg": "", "Pojemność skokowa": "",
                          "Rodzaj paliwa": " ", "Moc": " ", "Skrzynia biegów": " ",
                          "Napęd": " ", "Liczba drzwi": " ", "Liczba miejsc": " ",
                          "Kraj pochodzenia": " ", "Data pierwszej rejestracji w historii pojazdu": " ",
                          "Zarejestrowany w Polsce": " ", "Pierwszy właściciel (od nowości)": " ", "Bezwypadkowy": " ",
                          "Serwisowany w ASO": " ", "Stan": " ","Numer rejestracyjny pojazdu":" ",
                          "Spalanie W Mieście":" ","Spalanie Poza Miastem":" ","Wersja":" ","Emisja":" ",
                          "Okres gwarancji producenta":" ","Pokaż oferty z numerem VIN":" ","Możliwość finansowania":" ",
                          "Leasing": " "}

marka = bs.find_all(class_="ooa-162vy3d e18eslyg3")

for info in marka:
    
    for key in mymap:
        
            if bool(re.search(f"{key}", info.get_text())):

                new = re.sub(f"{key}", r"", info.get_text())
                mymap[key] = new
print(mymap)
# Out:
# {'Oferta od': 'Firma', 'Marka pojazdu': 'Audi', 'Model pojazdu': 'A5', 'Typ nadwozia': 'Coupe', 'Generacja': '8T (2007-2016)', 'Kolor': 'Czarny', 'Rodzaj koloru': 'Metalik', 'Rok produkcji': '2014', 'Przebieg': '203 000 km', 'Pojemność skokowa': '1 968 cm3', 'Rodzaj paliwa': 'Diesel', 'Moc': '177 KM', 'Skrzynia biegów': 'Manualna', 'Napęd': '4x4 (stały)', 'Liczba drzwi': '5', 'Liczba miejsc': '5', 'Kraj pochodzenia': 'Niemcy', 'Data pierwszej rejestracji w historii pojazdu': ' ', 'Zarejestrowany w Polsce': 'Tak', 'Pierwszy właściciel (od nowości)': ' ', 'Bezwypadkowy': 'Tak', 'Serwisowany w ASO': 'Tak', 'Stan': 'Używane', 'Numer rejestracyjny pojazdu': ' ', 'Spalanie W Mieście': '5,50 l/100km', 'Spalanie Poza Miastem': '3.7 l/100km', 'Wersja': '2.0 TDI Sportback quattro DPF', 'Emisja': ' CO2108 g/km', 'Okres gwarancji producenta': ' ', 'Pokaż oferty z numerem VIN': 'Tak', 'Możliwość finansowania': 'Tak', 'Leasing': 'Tak'}
